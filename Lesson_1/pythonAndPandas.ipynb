# %%
import pandas as pd

can_lang = pd.read_csv('data/can_lang.csv')

ab_lang = can_lang[can_lang["category"] == "Aboriginal languages"]

# %%
ab_lang[["language", "mother_tongue"]]
# Out:
#                          language  mother_tongue
# 0    Aboriginal languages, n.o.s.            590
# 5    Algonquian languages, n.i.e.             45
# 6                       Algonquin           1260
# 12   Athabaskan languages, n.i.e.             50
# 13                      Atikamekw           6150
# ..                            ...            ...
# 191        Thompson (Ntlakapamux)            335
# 195                       Tlingit             95
# 196                     Tsimshian            200
# 206    Wakashan languages, n.i.e.             10
# 210                    Woods Cree           1840
#
# [67 rows x 2 columns]

# %%
aboriginal_lang = can_lang.loc[can_lang["category"] == "Aboriginal languages", ["language", "mother_tongue"]]

# %%
aboriginal_lang
# Out:
#                          language  mother_tongue
# 0    Aboriginal languages, n.o.s.            590
# 5    Algonquian languages, n.i.e.             45
# 6                       Algonquin           1260
# 12   Athabaskan languages, n.i.e.             50
# 13                      Atikamekw           6150
# ..                            ...            ...
# 191        Thompson (Ntlakapamux)            335
# 195                       Tlingit             95
# 196                     Tsimshian            200
# 206    Wakashan languages, n.i.e.             10
# 210                    Woods Cree           1840
#
# [67 rows x 2 columns]

# %%
arranged_lang = aboriginal_lang.sort_values(by="mother_tongue", ascending=False)

# %%
ten_lang = arranged_lang.head(10)

# %%
ten_lang
# Out:
#               language  mother_tongue
# 40        Cree, n.o.s.          64050
# 89           Inuktitut          35210
# 138            Ojibway          17885
# 137           Oji-Cree          12855
# 48                Dene          10700
# 125  Montagnais (Innu)          10235
# 119            Mi'kmaq           6690
# 13           Atikamekw           6150
# 149        Plains Cree           3065
# 180             Stoney           3025

# %%
canadian_population = 35_151_728
ten_lang["mother_tongue_percent"] = (ten_lang["mother_tongue"]/canadian_population) * 100
# Out:
# C:\Users\fc196mega\AppData\Local\Temp\ipykernel_28960\3124839349.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ten_lang["mother_tongue_percent"] = (ten_lang["mother_tongue"]/canadian_population) * 100

# %%
ten_lang
# Out:
#               language  mother_tongue  mother_tongue_percent
# 40        Cree, n.o.s.          64050               0.182210
# 89           Inuktitut          35210               0.100166
# 138            Ojibway          17885               0.050879
# 137           Oji-Cree          12855               0.036570
# 48                Dene          10700               0.030439
# 125  Montagnais (Innu)          10235               0.029117
# 119            Mi'kmaq           6690               0.019032
# 13           Atikamekw           6150               0.017496
# 149        Plains Cree           3065               0.008719
# 180             Stoney           3025               0.008606

# %%
aboriginal_lang = can_lang.loc[
    can_lang["category"] == "Aboriginal languages",
    ["language", "mother_tongue"]
]
arranged_lang = aboriginal_lang.sort_values(
    by="mother_tongue",
    ascending=False
)
ten_lang = arranged_lang.head(10)
ten_lang
# Out:
#               language  mother_tongue
# 40        Cree, n.o.s.          64050
# 89           Inuktitut          35210
# 138            Ojibway          17885
# 137           Oji-Cree          12855
# 48                Dene          10700
# 125  Montagnais (Innu)          10235
# 119            Mi'kmaq           6690
# 13           Atikamekw           6150
# 149        Plains Cree           3065
# 180             Stoney           3025

# %%
ten_lang = (
    can_lang.loc[
        can_lang["category"] == "Aboriginal languages", 
        ["language", "mother_tongue"]]
        .sort_values(by="mother_tongue", ascending=False)
        .head(10)
)
ten_lang
# Out:
#               language  mother_tongue
# 40        Cree, n.o.s.          64050
# 89           Inuktitut          35210
# 138            Ojibway          17885
# 137           Oji-Cree          12855
# 48                Dene          10700
# 125  Montagnais (Innu)          10235
# 119            Mi'kmaq           6690
# 13           Atikamekw           6150
# 149        Plains Cree           3065
# 180             Stoney           3025

# %%
import altair as alt

# %%
bar_plot_mother_tongue = alt.Chart(ten_lang).mark_bar().encode(
    x=alt.X("mother_tongue").title("Mother Tongue (Number of Canadian Residents)"),
    y=alt.Y("language").title("Language")
)

# %%
bar_plot_mother_tongue
# Out:
# alt.Chart(...)

# %%
bar_plot_mother_tongue = alt.Chart(ten_lang).mark_bar().encode(
    x=alt.X("mother_tongue").title("Mother Tongue (Number of Canadian Residents)"),
    y=alt.Y("language").sort("x").title("Language")
)

# %%
bar_plot_mother_tongue
# Out:
# alt.Chart(...)

# %%
# load the data
can_lang = pd.read_csv('data/can_lang.csv')

# top 10 Aboriginal Languages
ten_lang = (
    can_lang.loc[
        can_lang["category"] == "Aboriginal languages",
        ["language", "mother_tongue"]
    ]
    .sort_values(by="mother_tongue", ascending=False)
    .head(10)
)

# Bar Chart
ten_lang_plot = alt.Chart(ten_lang).mark_bar().encode(
    x=alt.X("mother_tongue").title("Mother Tongue (Number of Canadian Residents)"),
    y=alt.Y("language").sort("x").title("Language")
)
ten_lang_plot
# Out:
# alt.Chart(...)
